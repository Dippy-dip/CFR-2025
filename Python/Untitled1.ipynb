# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
cinc_ohio_data = pd.read_csv("C:/Users/dm4235/Downloads/cincinnati_barchart.csv")

cinc_ohio_data['month'] = pd.to_datetime(cinc_ohio_data['month'])
cinc_ohio_data = cinc_ohio_data.sort_values(by='month')
plt.plot(cinc_ohio_data['month'],cinc_ohio_data['month_filings'])

print(cinc_ohio_data)
# Out:
#         month  month_last_day  month_filings  avg_filings  percentage_diff
# 0  2020-01-01             NaN           1143       1025.5         1.114578
# 6  2020-02-01             NaN            887       1197.5         0.740710
# 12 2020-03-01             NaN            527        875.5         0.601942
# 18 2020-04-01             NaN            239        941.0         0.253985
# 24 2020-05-01             NaN            328       1112.5         0.294831
# ..        ...             ...            ...          ...              ...
# 5  2025-01-01             NaN           1158       1025.5         1.129205
# 11 2025-02-01             NaN           1082       1175.5         0.920459
# 17 2025-03-01             NaN            934        875.5         1.066819
# 23 2025-04-01             NaN           1024        941.0         1.088204
# 29 2025-05-01             NaN           1040       1112.5         0.934831
#
# [65 rows x 5 columns]
# ...
